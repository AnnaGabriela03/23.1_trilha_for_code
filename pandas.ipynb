# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaGabriela03/23.1_trilha_for_code/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# ainda n tem o arquivo em excel 💀
dados = pd.read_excel("/content/db.xlsx")
dados

# %%
dados["Numero Preferido"]*3

# %%
dados["Numero Preferido"] = dados["Numero Preferido"]*3

# %%
dados_csv = pd.read_csv("/teste.csv")
dados_csv
# Out:
#    idade        nome        curso
# 0     20   guilherme   engenharia
# 1     20        davi   engenharia
